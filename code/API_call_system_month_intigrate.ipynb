# %% [markdown]
# ## 장애인콜 시스템

# %%
# modules
import requests
import pprint
import json
import tqdm

from os import name
import xml.etree.ElementTree as et
import pandas as pd
import bs4
from lxml import html
from urllib.parse import urlencode, quote_plus, unquote

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(31)):
    # date and url
    date = 20191201 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [06:56<00:00, 13.45s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(28)):
    # date and url
    date = 20190201 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 28/28 [05:17<00:00, 11.36s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(30)):
    # date and url
    date = 20190401 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [07:35<00:00, 15.17s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(30)):
    # date and url
    date = 20190601 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [06:27<00:00, 12.92s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(30)):
    # date and url
    date = 20190901 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [06:46<00:00, 13.54s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(30)):
    # date and url
    date = 20191101 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [06:54<00:00, 13.81s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(31)):
    # date and url
    date = 20190101 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [06:34<00:00, 12.72s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(31)):
    # date and url
    date = 20190301 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [06:31<00:00, 12.62s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(31)):
    # date and url
    date = 20190501 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [07:07<00:00, 13.79s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(31)):
    # date and url
    date = 20190701 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [07:41<00:00, 14.89s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(31)):
    # date and url
    date = 20190801 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [07:16<00:00, 14.07s/it]

# %%
cum_data = pd.DataFrame()
for i in tqdm.tqdm(range(31)):
    # date and url
    date = 20191001 + i
    inti = str(date//100)
    url = "http://openapi.seoul.go.kr:8088/487250446b7769733130346674635266/xml/disabledCalltaxi/1/1000/" + str(date)

    # get xml data for url
    response = requests.get(url)
    contents = response.text

    # check contents
    pp = pprint.PrettyPrinter(indent=4)

    # check xml
    xml_obj = bs4.BeautifulSoup(contents,'lxml-xml')
    rows = xml_obj.findAll('item')

    # 각 행의 컬럼, 이름, 값을 가지는 리스트 만들기
    row_list = [] # 행값
    name_list = [] # 열이름값
    value_list = [] #데이터값

    # xml 안의 데이터 수집
    for i in range(0, len(rows)):
        columns = rows[i].find_all()
        #첫째 행 데이터 수집
        for j in range(0,len(columns)):
            if i ==0:
                # 컬럼 이름 값 저장
                name_list.append(columns[j].name)
            # 컬럼의 각 데이터 값 저장
            value_list.append(columns[j].text)
        # 각 행의 value값 전체 저장
        row_list.append(value_list)
        # 데이터 리스트 값 초기화
        value_list=[]

    #xml값 DataFrame으로 만들기
    calltaxi_df = pd.DataFrame(row_list)
    calltaxi_df.columns = ['no', 'cartype', 'receipttime', 'settime',
                       'ridetime', 'startpos1', 'startpos2', 'endpos1', 'endpos2']


    cum_data = pd.concat([cum_data, calltaxi_df], axis=0)

#DataFrame CSV 파일로 저장
cum_data.to_csv(inti+'콜택시.csv', encoding='utf-8-sig')
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [07:30<00:00, 14.54s/it]
